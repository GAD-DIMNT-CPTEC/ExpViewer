# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

import hvplot.xarray
import holoviews as hv

hv.extension("bokeh")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7fdc801f-f2a6-4516-aa00-bc88769a83a5'>
#   <div id="df107335-88c9-4468-8f36-455381f8fd71" data-root-id="7fdc801f-f2a6-4516-aa00-bc88769a83a5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
ds_pslc = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_pslc.zarr')
ds_psnm = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_psnm.zarr')
ds_uvel = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_uvel.zarr')
ds_vvel = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_vvel.zarr')
ds_temp = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_temp.zarr')
ds_umes = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_umes.zarr')
ds_zgeo = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_zgeo.zarr')
ds_agpl = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_agpl.zarr')
ds_tp2m = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_tp2m.zarr')
ds_u10m = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_u10m.zarr')
ds_v10m = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_v10m.zarr')
ds_q02m = xr.open_zarr('/mnt/beegfs/carlos.bastarz/SMNA_v3.0.x_check/anls_compare/pos/convert_to_netcdf/output/zarr/EXPS_SCORES_q02m.zarr')

# %%
ds_pslc
# Out:
# <xarray.Dataset> Size: 37kB
# Dimensions:     (exp: 7, lead: 4, cycle: 306)
# Coordinates:
#   * exp         (exp) <U4 112B 'EXP1' 'EXP2' 'EXP3' 'EXP4' 'EXP5' 'EXP6' 'EXP7'
#   * lead        (lead) int64 32B 0 1 2 3
#   * cycle       (cycle) int64 2kB 0 1 2 3 4 5 6 ... 299 300 301 302 303 304 305
# Data variables:
#     bias_cycle  (exp, lead) float64 224B dask.array<chunksize=(7, 4), meta=np.ndarray>
#     bias_lead   (exp, cycle) float64 17kB dask.array<chunksize=(7, 306), meta=np.ndarray>
#     rmse_cycle  (exp, lead) float64 224B dask.array<chunksize=(7, 4), meta=np.ndarray>
#     rmse_lead   (exp, cycle) float64 17kB dask.array<chunksize=(7, 306), meta=np.ndarray>

# %%
ds_psnm = ds_psnm.sel(exp=['EXP1', 'EXP3', 'EXP4', 'EXP5', 'EXP6', 'EXP7'])
ds_temp = ds_temp.sel(exp=['EXP1', 'EXP3', 'EXP4', 'EXP5', 'EXP6', 'EXP7'])
ds_zgeo = ds_zgeo.sel(exp=['EXP1', 'EXP3', 'EXP4', 'EXP5', 'EXP6', 'EXP7'])

# %%
hline = hv.HLine(0).opts(color='black', line_dash='dashed')

# %%
(ds_pslc['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_pslc['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_pslc['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_pslc['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .Overlay.I   :Overlay
#       .NdOverlay.I :NdOverlay   [exp]
#          :Curve   [lead]   (bias_cycle)
#       .HLine.I     :HLine   [x,y]
#    .Overlay.II  :Overlay
#       .NdOverlay.I :NdOverlay   [exp]
#          :Curve   [lead]   (rmse_cycle)
#       .HLine.I     :HLine   [x,y]
#    .Overlay.III :Overlay
#       .NdOverlay.I :NdOverlay   [exp]
#          :Curve   [cycle]   (bias_lead)
#       .HLine.I     :HLine   [x,y]
#    .Overlay.IV  :Overlay
#       .NdOverlay.I :NdOverlay   [exp]
#          :Curve   [cycle]   (rmse_lead)
#       .HLine.I     :HLine   [x,y]

# %%
(ds_psnm['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_psnm['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_psnm['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_psnm['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .Overlay.I   :Overlay
#       .NdOverlay.I :NdOverlay   [exp]
#          :Curve   [lead]   (bias_cycle)
#       .HLine.I     :HLine   [x,y]
#    .Overlay.II  :Overlay
#       .NdOverlay.I :NdOverlay   [exp]
#          :Curve   [lead]   (rmse_cycle)
#       .HLine.I     :HLine   [x,y]
#    .Overlay.III :Overlay
#       .NdOverlay.I :NdOverlay   [exp]
#          :Curve   [cycle]   (bias_lead)
#       .HLine.I     :HLine   [x,y]
#    .Overlay.IV  :Overlay
#       .NdOverlay.I :NdOverlay   [exp]
#          :Curve   [cycle]   (rmse_lead)
#       .HLine.I     :HLine   [x,y]

# %%
(ds_uvel['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_uvel['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_uvel['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_uvel['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]

# %%
(ds_vvel['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_vvel['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_vvel['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_vvel['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]

# %%
(ds_temp['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_temp['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_temp['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_temp['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]

# %%
(ds_umes['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_umes['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_umes['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_umes['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]

# %%
(ds_zgeo['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_zgeo['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_zgeo['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_zgeo['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [plev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]

# %%
(ds_agpl['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_agpl['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_agpl['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_agpl['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [lev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [lev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [lev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [lev]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]

# %%
(ds_tp2m['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_tp2m['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_tp2m['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_tp2m['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [height]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [height]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [height]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [height]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]

# %%
(ds_u10m['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_u10m['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_u10m['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_u10m['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [height_2]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [height_2]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [height_2]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [height_2]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]

# %%
(ds_v10m['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_v10m['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_v10m['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_v10m['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [height_2]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [height_2]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [height_2]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [height_2]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]

# %%
(ds_q02m['bias_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_q02m['rmse_cycle'].hvplot.line(x='lead', by='exp') * hline + ds_q02m['bias_lead'].hvplot.line(x='cycle', by='exp') * hline + ds_q02m['rmse_lead'].hvplot.line(x='cycle', by='exp') * hline).cols(2)
# Out:
# :Layout
#    .DynamicMap.I   :DynamicMap   [height]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (bias_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.II  :DynamicMap   [height]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [lead]   (rmse_cycle)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.III :DynamicMap   [height]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (bias_lead)
#          .HLine.I     :HLine   [x,y]
#    .DynamicMap.IV  :DynamicMap   [height]
#       :Overlay
#          .NdOverlay.I :NdOverlay   [exp]
#             :Curve   [cycle]   (rmse_lead)
#          .HLine.I     :HLine   [x,y]
